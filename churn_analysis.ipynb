# %%
# charn analysis
# import lbraries
import  pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\data analysis\python  project  analaysis list\new\Churn.csv")
df.head(100)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# ..         ...     ...            ...     ...        ...     ...          ...
# 95  8637-XJIVR  Female              0      No         No      12          Yes
# 96  9803-FTJCG    Male              0     Yes        Yes      71          Yes
# 97  0278-YXOOG    Male              0      No         No       5          Yes
# 98  3212-KXOCR    Male              0      No         No      52          Yes
# 99  4598-XLKNJ  Female              1     Yes         No      25          Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# replacing blank as 0 tenure is 0 and no total charges recorded

# %%
df['TotalCharges']= df['TotalCharges'].replace(" " , "0")
df['TotalCharges']= df['TotalCharges'].astype("float64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# checking if any null is there

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['customerID'].duplicated().sum()
# Out:
# 0

# %%
#converting 0 /1 to no/yes for senion citizen to make easy to understand

# %%
def conv(value):
    if value== 1:
        return "Yes"
    else :
        return "No"

df['SeniorCitizen']= df['SeniorCitizen'].apply(conv)
df.head(100)
# Out:
#     customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female            No     Yes         No       1           No
# 1   5575-GNVDE    Male            No      No         No      34          Yes
# 2   3668-QPYBK    Male            No      No         No       2          Yes
# 3   7795-CFOCW    Male            No      No         No      45           No
# 4   9237-HQITU  Female            No      No         No       2          Yes
# ..         ...     ...           ...     ...        ...     ...          ...
# 95  8637-XJIVR  Female            No      No         No      12          Yes
# 96  9803-FTJCG    Male            No     Yes        Yes      71          Yes
# 97  0278-YXOOG    Male            No      No         No       5          Yes
# 98  3212-KXOCR    Male            No      No         No      52          Yes
# 99  4598-XLKNJ  Female           Yes     Yes         No      25          Yes
#
# ...

# %%
ax= sns.countplot(x='Churn', data = df)
ax.bar_label(ax.containers[0])
plt.title("count of charn")
plt.show()

# %%
gb=df.groupby('Churn').agg({'Churn':'count'})
plt.pie(gb['Churn'], labels=gb.index,autopct='%1.2f%%')
plt.title('Percentage Of Charned Customers')
plt.show()

# %%
sns.countplot(x='gender', data = df ,hue= 'Churn')

plt.show()

# %%
# charn by gender

# %%
sns.countplot(x='SeniorCitizen', data = df ,hue= 'Churn')
plt.title("Charn by SeniorCitizen")
plt.show()

# %%
# Step 1: Create crosstab
ct = pd.crosstab(df['SeniorCitizen'], df['Churn'], normalize='index') * 100

# Step 2: Plot stacked bar
ax = ct.plot(kind='bar', stacked=True, )

# Step 3: Add percentage labels
for i, row in enumerate(ct.values):
    cum_height = 0
    for j, val in enumerate(row):
        if val > 0:
            ax.text(i, cum_height + val/2, f'{val:.1f}%', ha='center', va='center', color='white', fontsize=10)
            cum_height += val

# Step 4: Titles and labels
plt.title("Churn by SeniorCitizen (in %)")
plt.ylabel("Percentage")
plt.xlabel("SeniorCitizen")
plt.legend(title="Churn")
plt.ylim(0, 100)
plt.tight_layout()
plt.show()

# %%
#Churn rate among senior citizens is significantly higher (41.7%) 
#compared to non-senior customers (23.6%), indicating a critical retention gap.

# %%
sns.histplot(x="tenure", data= df, bins= 72,hue= 'Churn')
# Out:
# <Axes: xlabel='tenure', ylabel='Count'>

# %%
# people who use service for a long time have stayed but who use service for 1-2 months of service have charned

# %%
ax= sns.countplot(x='Contract', data = df , hue = "Churn")
ax.bar_label(ax.containers[0])
plt.title("count of customers by Contract ")
plt.show()

# %%
#Customers on month-to-month contracts have the highest churn, while those on one-year or two-year contracts show significantly lower churn rates,
#indicating that longer commitments improve retention.

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
# List of service columns
cols = ['PhoneService', 'MultipleLines', 'InternetService',
        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
        'TechSupport', 'StreamingTV', 'StreamingMovies']

# Set figure size based on number of plots
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(18, 12))
axes = axes.flatten()

# Loop through columns and create countplots
for i, col in enumerate(cols):
    sns.countplot(x=df[col], ax=axes[i],hue = df["Churn"])
    axes[i].set_title(f'Countplot of {col}')
    axes[i].tick_params(axis='x', rotation=0)
    axes[i].set_ylabel("Count")

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# The subplots show that churn is noticeably higher among customers who do not use optional services like OnlineSecurity, TechSupport, and DeviceProtection.
# Customers with no internet service or no phone service show very low churn, likely due to limited engagement.
# In contrast, users subscribed to streaming and backup services also show reduced churn, indicating that bundled services may improve retention.

# %%
ax= sns.countplot(x='PaymentMethod', data = df , hue = "Churn")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.title("count of customers by Contract ")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# customer may churn when the use payment method as electronic check

# %% [markdown]
# Customers with Paperless Billing churn more (~33%) than paper bill users (~17%).

# %%
ax= sns.countplot(x='PaperlessBilling', data = df , hue = "Churn")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.title("count of customers by PaperlessBilling ")
plt.xticks(rotation=30)
plt.show()

# %%
 # 	Dependents
ax= sns.countplot(x='Dependents', data = df , hue = "Churn")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.title("count of customers by Dependents ")
plt.xticks(rotation=30)
plt.show()

# %%
ax= sns.countplot(x='Partner', data = df , hue = "Churn")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.title("count of customers by Partner ")
plt.xticks(rotation=30)
plt.show()
